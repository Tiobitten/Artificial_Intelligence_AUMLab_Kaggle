# %%
### 1. Neural Network Model 4 - Final Exam ###
### Fashion-MNIST as a CNN

# Import the libraries that will be needed.

print('Importing libraries...')
import os
import time
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Set level of TF screen logging suppression {'0', '1', '2'}
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
print('TensorFlow version', tf.__version__)
print('Done.')
# Out:
# Importing libraries...
# TensorFlow version 2.12.0
# Done.

# %%
# 2. Load training data

print('Loading training data...')
train = pd.read_csv('fashion-mnist_train.csv')
print('Done.')
# Out:
# Loading training data...
# Done.

# %%
# 3. Here is where your class images, the test data, are being loaded
print('Loading test data...')
test = pd.read_csv('classTest.csv')
print('Done.')
# Out:
# Loading test data...
# Done.

# %%
# 4. Shape data for training and testing

#Store first column as target vector
train_labels = np.array(train.label)
test_labels = np.array(test.label)

train.drop('label',axis=1, inplace=True)
test.drop('label',axis=1, inplace=True)

#Reshape - adding one more dimension to each image
train_data = np.array(train).reshape(train.shape[0],28,28,1)
test_data = np.array(test).reshape(test.shape[0],28,28,1)

#Print shapes
print('Train tensor shape: ',train_data.shape)
print('Test tensor shape: ',test_data.shape)
print('Single image shape:', train_data[0].shape)
print('Train_labels shape:', train_labels.shape)
print('Test_labels shape:', test_labels.shape)
# Out:
# Train tensor shape:  (60000, 28, 28, 1)
# Test tensor shape:  (138, 28, 28, 1)
# Single image shape: (28, 28, 1)
# Train_labels shape: (60000,)
# Test_labels shape: (138,)

# %%
# 5. Create label names
label_names = ["T-shirt/top","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]

# %%
# 6. Show some of the training data images

import random
plt.figure(figsize=(15,7))
for i in range(12):
    ax=plt.subplot(3,4,i+1)
    rand_index=random.choice(range(len(train_data)))
    plt.imshow(train_data[rand_index], cmap=plt.cm.binary)
    plt.axis(False)
    plt.title(label_names[train_labels[rand_index]])

# %%
# 7. Normalize the data

train_norm = train_data / 255.0
test_norm = test_data / 255.0

X_train = train_norm[10000:]
y_train = train_labels[10000:]

X_valid = train_norm[:10000]
y_valid = train_labels[:10000]

# %%
# 8. Build the CNN model

#Set random seed

import os
import time
import tensorflow as tf


tf.random.set_seed(42)

#Create model
model = tf.keras.Sequential([
    
    tf.keras.layers.Conv2D(filters=5, kernel_size=2, strides=1, padding="same", activation="relu",
                           input_shape=(28,28,1)), 
    tf.keras.layers.Conv2D(10,3, padding="valid", activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(15,3, padding="valid", activation='relu'),
    tf.keras.layers.Conv2D(20,3, padding="valid", activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(25,3, padding="valid", activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation="softmax") #Output layer

])

# %%
# 9. Compile the model
#
# You set the learning rate in this code block.
# Original learning rate = 0.001

model.compile(loss="sparse_categorical_crossentropy",
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
               metrics=["accuracy"])

#Show summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 28, 28, 5)         25
#
#  conv2d_6 (Conv2D)           (None, 26, 26, 10)        460
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 10)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 15)        1365
#
#  conv2d_8 (Conv2D)           (None, 9, 9, 20)          2720
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 20)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 25)          4525
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 25)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25)                0
#
#  dense_1 (Dense)             (None, 10)                260
#
# =================================================================
# Total params: 9,355
# Trainable params: 9,355
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 10. Train the CNN model
#
# You set the number of epochs and batch size in this code block

starting_time = time.time()
print("Training started...")

# Original: epochs = 5, batch_size = 32
history = model.fit(X_train, y_train,
                    epochs=50,batch_size=32,
                    validation_data=(X_valid,y_valid), verbose=1
                    )

print("Training ended.")
ending_time = time.time()
print('Time to train model: {:.4f}'.format(ending_time - starting_time),'seconds.')
# Out:
# Training started...
# Epoch 1/50
# 1563/1563 [==============================] - 57s 35ms/step - loss: 0.6809 - accuracy: 0.7492 - val_loss: 0.4821 - val_accuracy: 0.8240
# Epoch 2/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.4561 - accuracy: 0.8356 - val_loss: 0.4144 - val_accuracy: 0.8527
# Epoch 3/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.3914 - accuracy: 0.8578 - val_loss: 0.3736 - val_accuracy: 0.8663
# Epoch 4/50
# 1563/1563 [==============================] - 52s 34ms/step - loss: 0.3558 - accuracy: 0.8719 - val_loss: 0.3425 - val_accuracy: 0.8741
# Epoch 5/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.3318 - accuracy: 0.8805 - val_loss: 0.3303 - val_accuracy: 0.8778
# Epoch 6/50
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.3155 - accuracy: 0.8861 - val_loss: 0.3173 - val_accuracy: 0.8830
# Epoch 7/50
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.3004 - accuracy: 0.8920 - val_loss: 0.3049 - val_accuracy: 0.8878
# Epoch 8/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.2886 - accuracy: 0.8969 - val_loss: 0.2972 - val_accuracy: 0.8908
# Epoch 9/50
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.2807 - accuracy: 0.8982 - val_loss: 0.2955 - val_accuracy: 0.8906
# Epoch 10/50
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.2724 - accuracy: 0.9016 - val_loss: 0.2913 - val_accuracy: 0.8936
# Epoch 11/50
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.2649 - accuracy: 0.9026 - val_loss: 0.3115 - val_accuracy: 0.8864
# Epoch 12/50
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.2586 - accuracy: 0.9064 - val_loss: 0.2995 - val_accuracy: 0.8903
# Epoch 13/50
# 1563/1563 [==============================] - 54s 34ms/step - loss: 0.2524 - accuracy: 0.9081 - val_loss: 0.2824 - val_accuracy: 0.8982
# Epoch 14/50
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.2467 - accuracy: 0.9092 - val_loss: 0.3008 - val_accuracy: 0.8906
# Epoch 15/50
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.2432 - accuracy: 0.9122 - val_loss: 0.2875 - val_accuracy: 0.8954
# Epoch 16/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.2360 - accuracy: 0.9133 - val_loss: 0.2783 - val_accuracy: 0.8962
# Epoch 17/50
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.2309 - accuracy: 0.9144 - val_loss: 0.2912 - val_accuracy: 0.8927
# Epoch 18/50
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.2273 - accuracy: 0.9160 - val_loss: 0.2824 - val_accuracy: 0.8971
# Epoch 19/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.2257 - accuracy: 0.9163 - val_loss: 0.2935 - val_accuracy: 0.8946
# Epoch 20/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.2212 - accuracy: 0.9190 - val_loss: 0.2769 - val_accuracy: 0.8974
# Epoch 21/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.2191 - accuracy: 0.9188 - val_loss: 0.2830 - val_accuracy: 0.8984
# Epoch 22/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.2136 - accuracy: 0.9211 - val_loss: 0.2886 - val_accuracy: 0.8952
# Epoch 23/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.2100 - accuracy: 0.9226 - val_loss: 0.2807 - val_accuracy: 0.8960
# Epoch 24/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.2056 - accuracy: 0.9246 - val_loss: 0.2946 - val_accuracy: 0.8949
# Epoch 25/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.2054 - accuracy: 0.9228 - val_loss: 0.2915 - val_accuracy: 0.8998
# Epoch 26/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.2013 - accuracy: 0.9248 - val_loss: 0.2996 - val_accuracy: 0.8970
# Epoch 27/50
# 1563/1563 [==============================] - 57s 37ms/step - loss: 0.1971 - accuracy: 0.9273 - val_loss: 0.2844 - val_accuracy: 0.8970
# Epoch 28/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.1944 - accuracy: 0.9283 - val_loss: 0.3158 - val_accuracy: 0.8890
# Epoch 29/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.1938 - accuracy: 0.9272 - val_loss: 0.2947 - val_accuracy: 0.8961
# Epoch 30/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.1909 - accuracy: 0.9286 - val_loss: 0.2903 - val_accuracy: 0.8986
# Epoch 31/50
# 1563/1563 [==============================] - 54s 34ms/step - loss: 0.1866 - accuracy: 0.9300 - val_loss: 0.3264 - val_accuracy: 0.8913
# Epoch 32/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.1853 - accuracy: 0.9315 - val_loss: 0.3111 - val_accuracy: 0.8979
# Epoch 33/50
# 1563/1563 [==============================] - 57s 37ms/step - loss: 0.1834 - accuracy: 0.9313 - val_loss: 0.2934 - val_accuracy: 0.9007
# Epoch 34/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.1801 - accuracy: 0.9331 - val_loss: 0.3296 - val_accuracy: 0.8960
# Epoch 35/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.1796 - accuracy: 0.9327 - val_loss: 0.2949 - val_accuracy: 0.9023
# Epoch 36/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.1778 - accuracy: 0.9346 - val_loss: 0.2924 - val_accuracy: 0.8985
# Epoch 37/50
# 1563/1563 [==============================] - 59s 38ms/step - loss: 0.1747 - accuracy: 0.9341 - val_loss: 0.3120 - val_accuracy: 0.8995
# Epoch 38/50
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.1732 - accuracy: 0.9355 - val_loss: 0.3131 - val_accuracy: 0.9000
# Epoch 39/50
# 1563/1563 [==============================] - 54s 34ms/step - loss: 0.1722 - accuracy: 0.9349 - val_loss: 0.3156 - val_accuracy: 0.8958
# Epoch 40/50
# 1563/1563 [==============================] - 57s 37ms/step - loss: 0.1689 - accuracy: 0.9369 - val_loss: 0.3152 - val_accuracy: 0.8978
# Epoch 41/50
# 1563/1563 [==============================] - 59s 38ms/step - loss: 0.1684 - accuracy: 0.9367 - val_loss: 0.3250 - val_accuracy: 0.8915
# Epoch 42/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.1673 - accuracy: 0.9374 - val_loss: 0.3176 - val_accuracy: 0.8968
# Epoch 43/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.1657 - accuracy: 0.9384 - val_loss: 0.3336 - val_accuracy: 0.8932
# Epoch 44/50
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.1639 - accuracy: 0.9392 - val_loss: 0.3243 - val_accuracy: 0.8963
# Epoch 45/50
# 1563/1563 [==============================] - 59s 38ms/step - loss: 0.1617 - accuracy: 0.9399 - val_loss: 0.3091 - val_accuracy: 0.9019
# Epoch 46/50
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.1621 - accuracy: 0.9398 - val_loss: 0.3261 - val_accuracy: 0.8949
# Epoch 47/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.1585 - accuracy: 0.9409 - val_loss: 0.3387 - val_accuracy: 0.8942
# Epoch 48/50
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.1571 - accuracy: 0.9413 - val_loss: 0.3445 - val_accuracy: 0.8941
# Epoch 49/50
# 1563/1563 [==============================] - 54s 34ms/step - loss: 0.1575 - accuracy: 0.9402 - val_loss: 0.3186 - val_accuracy: 0.9020
# Epoch 50/50
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.1541 - accuracy: 0.9428 - val_loss: 0.3239 - val_accuracy: 0.8976
# Training ended.
# Time to train model: 2785.0028 seconds.

# %%
# 11. Plot the training and loss progress

pd.DataFrame(history.history).plot(title="Train and validation results",figsize=(10,7));

# %%
# 12. Get the accuracy of the class images test data

loss, accuracy = model.evaluate(test_norm, test_labels)
print('Test accuracy:' , accuracy * 100,'%')
# Out:
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2039 - accuracy: 0.9130
# Test accuracy: 91.30434989929199 %

# %%
# 13. Make predictions for the confusion matrix

y_probs = model.predict(test_norm)

#Convert prediction probabilities into integers
y_preds = y_probs.argmax(axis=1)
# Out:
# 5/5 [==============================] - 0s 9ms/step

# %%
# 14. Display the Confusion Matrix
cm=confusion_matrix(y_preds,test_labels)
#Plot
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=label_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax);

# %%
# Out:
# Requirement already satisfied: scikit-learn in c:\users\tiobi\anaconda3\lib\site-packages (1.2.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl (10.6 MB)
#      --------------------------------------- 10.6/10.6 MB 19.8 MB/s eta 0:00:00
# Collecting joblib>=1.2.0
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ---------------------------------------- 302.2/302.2 kB ? eta 0:00:00
# Requirement already satisfied: scipy>=1.6.0 in c:\users\tiobi\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tiobi\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\tiobi\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Installing collected packages: joblib, scikit-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.1
#     Uninstalling scikit-learn-1.2.1:
#       Successfully uninstalled scikit-learn-1.2.1
# Successfully installed joblib-1.3.2 scikit-learn-1.4.0

# %%
# Out:
# Requirement already satisfied: tensorflow in c:\users\tiobi\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.3)
# Requirement already satisfied: jax>=0.3.15 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.9.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.0)
# Requirement already satisfied: setuptools in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: packaging in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tiobi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\tiobi\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\tiobi\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\tiobi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tiobi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tiobi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tiobi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\tiobi\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\tiobi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tiobi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tiobi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tiobi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\tiobi\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tiobi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tiobi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
